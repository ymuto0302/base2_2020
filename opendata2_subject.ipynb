# %% [markdown]
# <a href="https://colab.research.google.com/github/ymuto0302/base2_2020/blob/master/opendata2_subject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # オープンデータの活用(2)：（課題）東京都のデータを用いた演習

# %%
# Google Drive のマウント
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
 
# CSV ファイルからデータ読み込み
df = pd.read_csv("/content/drive/My Drive/BASE2/OpenData/tokyo_covid19_20200604.csv")
df
# Out:
#         No  全国地方公共団体コード 都道府県名  市区町村名  ... 患者_症状 患者_渡航歴の有無フラグ  備考 退院済フラグ
# 0        1       130001   東京都    NaN  ...   NaN          NaN NaN    1.0
# 1        2       130001   東京都    NaN  ...   NaN          NaN NaN    1.0
# 2        3       130001   東京都    NaN  ...   NaN          NaN NaN    1.0
# 3        4       130001   東京都    NaN  ...   NaN          NaN NaN    1.0
# 4        5       130001   東京都    NaN  ...   NaN          NaN NaN    1.0
# ...    ...          ...   ...    ...  ...   ...          ...  ..    ...
# 5290  5174       130001   東京都    NaN  ...   NaN          NaN NaN    NaN
# 5291  5181       130001   東京都    NaN  ...   NaN          NaN NaN    NaN
# 5292  5182       130001   東京都    NaN  ...   NaN          NaN NaN    NaN
# 5293  5179       130001   東京都    NaN  ...   NaN          NaN NaN    NaN
# 5294  5176       130001   東京都    NaN  ...   NaN          NaN NaN    NaN
#
# [5295 rows x 16 columns]

# %%
# 可視化の準備
# matplotlib の機能のみではコードが長くなるため，PlotlyExpress を利用する
# 次行の "!pip ・・・・" は PlotlyExpress をインストールする手順
# !pip install plotly_express

# %%
'''
東京都 新型コロナウイルス陽性患者発表詳細
'''
import pandas as pd
 
# CSV ファイルからデータ読み込み
df = pd.read_csv("/content/drive/My Drive/BASE2/OpenData/tokyo_covid19_20200604.csv")

# 公表年月日，居住地，年代，性別のみを取り出す 
df = df.loc[:, ["公表_年月日", "患者_居住地", "患者_年代", "患者_性別"]]
print(df)

# 公表年月日および年代でグループ化して，"患者数[6月1日, 40台]=3人" のような構造を作る
df["カウント"] = 1 # 後ほど可視化（グラフ化）する際に利用するため，個々の患者に 1 を割り振る
df_count = df.groupby(["公表_年月日", "患者_年代"]).count().reset_index()
print(df_count)

# 可視化
import plotly_express as px
fig = px.bar(df_count, x="公表_年月日", y="カウント", color="患者_年代",
             title="東京都 新型コロナウイルス陽性患者発表詳細")
fig.show()
# Out:
#           公表_年月日  患者_居住地 患者_年代 患者_性別
# 0     2020-01-24  湖北省武漢市   40代    男性
# 1     2020-01-25  湖北省武漢市   30代    女性
# 2     2020-01-30  湖南省長沙市   30代    女性
# 3     2020-02-13      都内   70代    男性
# 4     2020-02-14      都内   50代    女性
# ...          ...     ...   ...   ...
# 5290  2020-06-03     NaN   40代    男性
# 5291  2020-06-03     NaN   40代    男性
# 5292  2020-06-03     NaN   40代    男性
# 5293  2020-06-03     NaN   50代    男性
# 5294  2020-06-03     NaN   70代    女性
#
# [5295 rows x 4 columns]
#          公表_年月日 患者_年代  患者_居住地  患者_性別  カウント
# 0    2020-01-24   40代       1      1     1
# 1    2020-01-25   30代       1      1     1
# 2    2020-01-30   30代       1      1     1
# 3    2020-02-13   70代       1      1     1
# 4    2020-02-14   50代       1      1     1
# ..          ...   ...     ...    ...   ...
# 659  2020-06-03   20代       0      2     2
# 660  2020-06-03   30代       0      4     4
# 661  2020-06-03   40代       0      4     4
# 662  2020-06-03   50代       0      1     1
# ...

# %%
'''
東京都 新型コロナウイルス陽性患者発表詳細
'''
import pandas as pd
 
# CSV ファイルからデータ読み込み
df = pd.read_csv("/content/drive/My Drive/BASE2/OpenData/tokyo_covid19_20200604.csv")

# 公表年月日，居住地，年代，性別のみを取り出す 
df = df.loc[:, ["公表_年月日", "患者_居住地", "患者_年代", "患者_性別"]]
print(df)

# 公表年月日および年代でグループ化して，"患者数[6月1日, 40台]=3人" のような構造を作る
df["カウント"] = 1 # 後ほど可視化（グラフ化）する際に利用するため，個々の患者に 1 を割り振る
df_count = df.groupby(["公表_年月日", "患者_性別"]).count().reset_index()
print(df_count)

# 可視化
import plotly_express as px
fig = px.bar(df_count, x="公表_年月日", y="カウント", color="患者_性別",
             title="東京都 新型コロナウイルス陽性患者発表詳細")
fig.show()
# Out:
#           公表_年月日  患者_居住地 患者_年代 患者_性別
# 0     2020-01-24  湖北省武漢市   40代    男性
# 1     2020-01-25  湖北省武漢市   30代    女性
# 2     2020-01-30  湖南省長沙市   30代    女性
# 3     2020-02-13      都内   70代    男性
# 4     2020-02-14      都内   50代    女性
# ...          ...     ...   ...   ...
# 5290  2020-06-03     NaN   40代    男性
# 5291  2020-06-03     NaN   40代    男性
# 5292  2020-06-03     NaN   40代    男性
# 5293  2020-06-03     NaN   50代    男性
# 5294  2020-06-03     NaN   70代    女性
#
# [5295 rows x 4 columns]
#          公表_年月日 患者_性別  患者_居住地  患者_年代  カウント
# 0    2020-01-24    男性       1      1     1
# 1    2020-01-25    女性       1      1     1
# 2    2020-01-30    女性       1      1     1
# 3    2020-02-13    男性       1      1     1
# 4    2020-02-14    女性       1      1     1
# ..          ...   ...     ...    ...   ...
# 195  2020-06-01    男性       9      9     9
# 196  2020-06-02    女性      17     17    17
# 197  2020-06-02    男性      17     17    17
# 198  2020-06-03    女性       0      6     6
# ...
