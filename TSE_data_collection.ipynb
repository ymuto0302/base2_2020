# %% [markdown]
# <a href="https://colab.research.google.com/github/ymuto0302/base2_2020/blob/master/TSE_data_collection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 東証一部上場企業の株価データの収集

# %% [markdown]
# ## (準備) Google Drive のマウント ＆ TSEデータ格納のためのディレクトリ作成

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# ディレクトリの作成
import os

path = '/content/drive/My Drive/TSEdata'
if os.path.exists(path) is False:
  os.mkdir('/content/drive/My Drive/TSEdata')

# %% [markdown]
# ## quandle のインストール

# %%
# !pip install quandl

# %% [markdown]
# ## 東証一部上場企業の株価データを Quandl から収集
# 以下のコードを実行する。
#
# ただし，実行に２時間程度を要するため，気長に待ちましょう。
#
# また，うまくデータを取得できたかは（コード中の）変数 path で指定したディレクトリを開けば分かります。

# %%
# Quandl から東証一部上場企業のデータを収集するコード

import pandas as pd
import quandl
import sys

quandl.ApiConfig.api_key = "swWCyaT7PznGyDJwoPys"

# (TODO) TSE_corp_list.csv のパスは各自の環境に合わせて変更すること
companies = pd.read_csv("/content/drive/My Drive/BASE2/EconomicData/TSE_corp_list.csv")

for code in companies['コード']:
    # print(code)
    indicator = "TSE/{}".format(code)
    path = "/content/drive/My Drive/TSEdata/{}.csv".format(code)
    
    # ファイルが既に存在する場合はスキップ
    if os.path.exists(path):
        print("data {} exist".format(indicator), file=sys.stderr)
    else:
        print("data {} collect ...".format(indicator), file=sys.stderr)
        data = quandl.get(indicator)
        data.to_csv(path) # CSV ファイルへの保存
# Out:
# data TSE/1301 collect ...
# data TSE/1332 collect ...
# data TSE/1333 collect ...
# data TSE/1352 collect ...
# data TSE/1376 collect ...
# data TSE/1377 collect ...
# data TSE/1379 collect ...
# data TSE/1384 collect ...
# data TSE/1413 collect ...
# data TSE/1414 collect ...
# data TSE/1417 collect ...
# data TSE/1419 collect ...
# data TSE/1420 collect ...
# data TSE/1429 collect ...
# data TSE/1430 collect ...
# data TSE/1433 collect ...
# data TSE/1435 collect ...
# data TSE/1514 collect ...
# data TSE/1515 collect ...
# data TSE/1518 collect ...
# data TSE/1605 collect ...
# data TSE/1662 collect ...
# data TSE/1663 collect ...
# data TSE/1712 collect ...
# data TSE/1716 collect ...
# data TSE/1717 collect ...
# data TSE/1719 collect ...
# data TSE/1720 collect ...
# data TSE/1721 collect ...
# data TSE/1726 collect ...
# data TSE/1762 collect ...
# data TSE/1766 collect ...
# data TSE/1768 collect ...
# data TSE/1780 collect ...
# data TSE/1801 collect ...
# ...
